# %% [markdown]
# ## Code By Luis Gonzalez
# ## Economic Complexity Over Time

# %%
# We will be using Pandas for reading al the relevant datasets.
import pandas as pd

# %%
df = pd.read_stata('rankings.dta')
# We make a time range

# %%
df
# Out:
#       location_id    year  sitc_eci    hs_eci  growth_proj sitc_eci_rank  \
# 0               2  1995.0 -2.001223 -2.148367          NaN           127
# 1               2  1996.0 -2.120867 -2.144461          NaN           129
# 2               2  1997.0 -1.800330 -1.424870          NaN           127
# 3               2  1998.0 -1.756738 -1.650229          NaN           127
# 4               2  1999.0 -1.703370 -1.384564          NaN           124
# 5               2  2000.0 -1.857626 -1.912659          NaN           131
# 6               2  2001.0 -2.140862 -1.440948          NaN           132
# 7               2  2002.0 -1.597537 -1.868593          NaN           130
# 8               2  2003.0 -1.884189 -1.930269          NaN           132
# 9               2  2004.0 -0.872460 -0.937312         4.46           105
# 10              2  2005.0 -1.920443 -1.609641         2.98           131
# 11              2  2006.0 -2.082978 -2.049579         2.89           133
# 12              2  2007.0 -2.026813 -1.650462         2.74           133
# 13              2  2008.0 -1.873189 -2.156115         2.77           132
# 14              2  2009.0 -1.440589 -0.821762         2.74           127
# 15              2  2010.0 -1.712401 -1.217842         2.56           130
# 16              2  2011.0 -1.488694 -1.120719         2.82           126
# 17              2  2012.0 -1.331899 -1.298046         2.81           121
# 18              2  2013.0 -1.143382 -1.028555         3.30           117
# 19              2  2014.0 -1.431019 -1.665862         2.39           125
# 20              2  2015.0 -1.383428 -1.640195         5.14           125
# 21              2  2016.0 -1.368060 -1.273833         3.66           125
# 22              2  2017.0 -1.822037 -1.669029         3.28           132
# 23              4  1995.0 -0.560130 -0.417942          NaN            88
# 24              4  1996.0 -0.389979 -0.282615          NaN            79
# 25              4  1997.0 -0.364675 -0.294792          NaN            78
# 26              4  1998.0 -0.346785 -0.312852          NaN            80
# 27              4  1999.0 -0.269458 -0.178165          NaN            71
# 28              4  2000.0 -0.129702 -0.051380          NaN            70
# 29              4  2001.0 -0.199870 -0.072271          NaN            73
# ...           ...     ...       ...       ...          ...           ...
# 3029          247  2011.0 -0.607533 -0.574716         5.34            94
# 3030          247  2012.0 -0.472990 -0.383309         5.56            89
# 3031          247  2013.0 -0.333912 -0.459253         5.76            79
# 3032          247  2014.0 -0.608637 -0.677570         5.55            95
# 3033          247  2015.0 -0.852070 -0.696792         4.72           104
# 3034          247  2016.0 -1.222425 -1.151687         4.01           123
# 3035          247  2017.0 -1.073317 -1.120620         3.20           116
# 3036          248  1995.0 -0.142538 -0.043938          NaN            65
# 3037          248  1996.0 -0.411419 -0.367138          NaN            80
# 3038          248  1997.0 -0.539845 -0.428631          NaN            81
# 3039          248  1998.0 -0.543744 -0.431621          NaN            88
# 3040          248  1999.0 -0.373663 -0.277202          NaN            81
# 3041          248  2000.0 -0.482915 -0.456307          NaN            85
# 3042          248  2001.0 -0.654431 -0.641292          NaN            96
# 3043          248  2002.0 -0.304022 -0.281891          NaN            77
# 3044          248  2003.0 -0.292525 -0.377807          NaN            78
# 3045          248  2004.0 -0.489555 -0.574572         5.49            86
# 3046          248  2005.0 -0.380699 -0.478661         5.54            80
# 3047          248  2006.0 -0.401259 -0.381994         5.48            84
# 3048          248  2007.0 -0.423282 -0.510323         5.46            82
# 3049          248  2008.0 -0.291236 -0.175637         5.72            77
# 3050          248  2009.0 -0.682110 -0.702853         5.14            95
# 3051          248  2010.0 -0.893220 -1.055467         5.02           109
# 3052          248  2011.0 -0.673546 -0.879405         4.92            98
# 3053          248  2012.0 -0.809828 -0.741473         4.76           104
# 3054          248  2013.0 -0.672232 -0.781233         5.08            97
# 3055          248  2014.0 -0.696330 -0.807621         4.93           100
# 3056          248  2015.0 -0.874097 -0.930933         4.73           108
# 3057          248  2016.0 -0.971397 -1.149360         4.71           109
# 3058          248  2017.0 -0.872061 -1.073362         4.15           106
#
#       hs_eci_rank code
# 0           217.0  AGO
# 1           215.0  AGO
# 2           204.0  AGO
# 3           206.0  AGO
# 4           202.0  AGO
# 5           227.0  AGO
# 6           219.0  AGO
# 7           229.0  AGO
# 8           228.0  AGO
# 9           188.0  AGO
# 10          223.0  AGO
# 11          230.0  AGO
# 12          224.0  AGO
# 13          229.0  AGO
# 14          186.0  AGO
# 15          213.0  AGO
# 16          210.0  AGO
# 17          218.0  AGO
# 18          199.0  AGO
# 19          228.0  AGO
# 20          225.0  AGO
# 21          213.0  AGO
# 22          227.0  AGO
# 23          147.0  ALB
# 24          132.0  ALB
# 25          126.0  ALB
# 26          131.0  ALB
# 27          120.0  ALB
# 28          119.0  ALB
# 29          126.0  ALB
# ...           ...  ...
# 3029        169.0  ZMB
# 3030        153.0  ZMB
# 3031        160.0  ZMB
# 3032        180.0  ZMB
# 3033        180.0  ZMB
# 3034        209.0  ZMB
# 3035        207.0  ZMB
# 3036        113.0  ZWE
# 3037        137.0  ZWE
# 3038        134.0  ZWE
# 3039        141.0  ZWE
# 3040        128.0  ZWE
# 3041        154.0  ZWE
# 3042        171.0  ZWE
# 3043        148.0  ZWE
# 3044        152.0  ZWE
# 3045        166.0  ZWE
# 3046        159.0  ZWE
# 3047        155.0  ZWE
# 3048        159.0  ZWE
# 3049        135.0  ZWE
# 3050        177.0  ZWE
# 3051        204.0  ZWE
# 3052        192.0  ZWE
# 3053        178.0  ZWE
# 3054        184.0  ZWE
# 3055        187.0  ZWE
# 3056        194.0  ZWE
# 3057        208.0  ZWE
# 3058        200.0  ZWE
#
# [3059 rows x 8 columns]
