# %% [markdown]
# ## Code By Luis Gonzalez
# ## Python code to create Top 20 Country COVID cases

# %% [markdown]
# ### Table of Contents
# * [Libraries](#Libraries)
# * [COVID Datasets](#COVID-Datasets)
#
#
# Here this code is available in a Gist Format:

# %% [markdown]
# Youtube Description:
#
# Top 20 Country Caseses over Time
#
#
#
# Source:
#
# Follow my Github for a Step-By-Step guide on how to build these types of visuals. (https://github.com/LuisEGV)

# %% [markdown]
# <a name="Libraries"></a>
# ### Libraries

# %%
# Here I will import Pandas to play around with the Covid Datasets
import pandas as pd

# %% [markdown]
# <a name="COVID-Datases"></a>
# ### COVID Datases

# %%
# Here I am importing a World Dataset from https://data.humdata.org/dataset/novel-coronavirus-2019-ncov-cases?force_layout=desktop
# I saved this dataset in the local folder

df = pd.read_csv('time_series_covid19_confirmed_global.csv')

# %%
# As we can see, some countries have a discrete row and other (feel free to see this for yourself) are broken down into provinces.
df.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/2020  1/23/2020  \
# 0            NaN    Afghanistan  33.0000  65.0000          0          0
# 1            NaN        Albania  41.1533  20.1683          0          0
# 2            NaN        Algeria  28.0339   1.6596          0          0
# 3            NaN        Andorra  42.5063   1.5218          0          0
# 4            NaN         Angola -11.2027  17.8739          0          0
#
#    1/24/2020  1/25/2020  1/26/2020  1/27/2020    ...     4/25/2020  4/26/2020  \
# 0          0          0          0          0    ...          1463       1531
# 1          0          0          0          0    ...           712        726
# 2          0          0          0          0    ...          3256       3382
# 3          0          0          0          0    ...           738        738
# 4          0          0          0          0    ...            25         26
#
# ...

# %%
# I will add all desceate countries in another dataset and then I will "compress" the countries with multiple regions into one country
# Here we can see all the unique countries.
df.iloc[:,1].unique()

# Now I added the multiple rows with the same country into one row.
df = df.groupby("Country/Region").sum()

# %%
# Here I showed the new dataset (feel free to take away ".head()" to see the full dataset)
# Latitude and Longitude get messed up doing the past sum, but I won't use them eitherway.
df.head()
# Out:
#                     Lat     Long  1/22/2020  1/23/2020  1/24/2020  1/25/2020  \
# Country/Region
# Afghanistan     33.0000  65.0000          0          0          0          0
# Albania         41.1533  20.1683          0          0          0          0
# Algeria         28.0339   1.6596          0          0          0          0
# Andorra         42.5063   1.5218          0          0          0          0
# Angola         -11.2027  17.8739          0          0          0          0
#
#                 1/26/2020  1/27/2020  1/28/2020  1/29/2020    ...     \
# Country/Region                                                ...
# Afghanistan             0          0          0          0    ...
# Albania                 0          0          0          0    ...
# Algeria                 0          0          0          0    ...
# Andorra                 0          0          0          0    ...
# Angola                  0          0          0          0    ...
#
# ...

# %%
df.to_csv('CleanedCOVIDdataset2.csv')
